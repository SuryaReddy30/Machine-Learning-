# %%
import pandas as pd
import numpy as np
a=pd.read_csv("WarnerCenturies.csv")

# %%
a.head()
# Out:
#    No.  Score        Against  Position  Innings                    Venue  \
# 0    1  123*     New Zealand         2        4   Bellerive Oval, Hobart
# 1    2    180          India         2        2       WACA Ground, Perth
# 2    3    163      Sri Lanka         1        1      The Gabba, Brisbane
# 3    4    100      Sri Lanka         2        1  Adelaide Oval, Adelaide
# 4    5    119   South Africa         1        1  Adelaide Oval, Adelaide
#
#   Ground       Date Result
# 0   Home  09-Dec-11   Lost
# 1   Home  13-Jan-12    Won
# 2   Home  04-Mar-12    Won
# 3   Home  06-Mar-12   Lost
# 4   Home  22-Nov-12  Drawn

# %%
s=a.groupby('Position')

# %%
for Position,Position_df in s:
    print("Position")
    print("Position_df")
    print("_______________________")
# Out:
# Position
# Position_df
# _______________________
# Position
# Position_df
# _______________________

# %%
a.iloc[:,1:4:2].head()
# Out:
#    Score  Position
# 0  123*          2
# 1    180         2
# 2    163         1
# 3    100         2
# 4    119         1

# %%
a.isnull().sum()
# Out:
# No.         0
# Score       0
# Against     0
# Position    0
# Innings     0
# Venue       0
# Ground      0
# Date        0
# Result      0
# dtype: int64

# %%
b=np.array(a)

# %%
a.iloc[:,:].values
# Out:
# array([[1, '123* ', ' New Zealand', 2, 4, 'Bellerive Oval, Hobart',
#         'Home', '09-Dec-11', 'Lost'],
#        [2, '180', ' India', 2, 2, 'WACA Ground, Perth', 'Home',
#         '13-Jan-12', 'Won'],
#        [3, '163', ' Sri Lanka', 1, 1, 'The Gabba, Brisbane', 'Home',
#         '04-Mar-12', 'Won'],
#        [4, '100', ' Sri Lanka', 2, 1, 'Adelaide Oval, Adelaide', 'Home',
#         '06-Mar-12', 'Lost'],
#        [5, '119', ' South Africa', 1, 1, 'Adelaide Oval, Adelaide',
#         'Home', '22-Nov-12', 'Drawn'],
#        [6, '124', ' England', 2, 3, 'The Gabba, Brisbane', 'Home',
#         '21-Nov-13', 'Won'],
#        [7, '112', ' England', 2, 3, 'WACA Ground, Perth', 'Home',
#         '13-Dec-13', 'Won'],
#        [8, '115', ' South Africa', 2, 3, 'SuperSport Park, Centurion',
#         'Away', '12-Feb-14', 'Won'],
#        [9, '135', ' South Africa', 2, 1,
#         'Newlands Cricket Ground, Cape Town', 'Away', '01-Mar-14', 'Won'],
# ...

# %%
a['Innings'].value_counts()
# Out:
# 1    23
# 2    13
# 3     7
# 4     2
# Name: Innings, dtype: int64

# %%
a.iloc[:,3:5].head()
# Out:
#    Position  Innings
# 0         2        4
# 1         2        2
# 2         1        1
# 3         2        1
# 4         1        1

# %%
a[['Position','Innings']].head()
# Out:
#    Position  Innings
# 0         2        4
# 1         2        2
# 2         1        1
# 3         2        1
# 4         1        1

# %%
a.describe()
# Out:
#              No.   Position    Innings
# count  45.000000  45.000000  45.000000
# mean   23.000000   1.511111   1.733333
# std    13.133926   0.505525   0.889331
# min     1.000000   1.000000   1.000000
# 25%    12.000000   1.000000   1.000000
# 50%    23.000000   2.000000   1.000000
# 75%    34.000000   2.000000   2.000000
# max    45.000000   2.000000   4.000000

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   No.       45 non-null     int64
#  1   Score     45 non-null     object
#  2   Against   45 non-null     object
#  3   Position  45 non-null     int64
#  4   Innings   45 non-null     int64
#  5   Venue     45 non-null     object
#  6   Ground    45 non-null     object
#  7   Date      45 non-null     object
#  8   Result    45 non-null     object
# dtypes: int64(3), object(6)
# memory usage: 3.3+ KB

# %%
#a[a['Score']>100]

# %%
a['Venue'].value_counts()
# Out:
# Adelaide Oval, Adelaide                          7
# Sydney Cricket Ground, Sydney                    7
# The Gabba, Brisbane                              5
# Melbourne Cricket Ground, Melbourne              5
# WACA Ground, Perth                               4
# Newlands Cricket Ground, Cape Town               3
# Bellerive Oval, Hobart                           1
# Sher-e-Bangla National Cricket Stadium, Dhaka    1
# Old Trafford, Manchester                         1
# Trent Bridge, Nottingham                         1
# County Ground, Taunton                           1
# M. Chinnaswamy Stadium, Bangalore                1
# Zohur Ahmed Chowdhury Stadium, Chittagong        1
# Kingsmead Cricket Ground, Durban                 1
# Manuka Oval, Canberra                            1
# Pallekele Cricket Stadium, Kandy                 1
# Warner Park, Basseterre                          1
# Dubai International Cricket Stadium, Dubai       1
# ...

# %%
a.to_excel("Test2.xlsx")

# %%
str(a)
# Out:
# '    No.  Score        Against  Position  Innings  \\\n0     1  123*     New Zealand         2        4   \n1     2    180          India         2        2   \n2     3    163      Sri Lanka         1        1   \n3     4    100      Sri Lanka         2        1   \n4     5    119   South Africa         1        1   \n5     6    124        England         2        3   \n6     7    112        England         2        3   \n7     8    115   South Africa         2        3   \n8     9    135   South Africa         2        1   \n9    10    145   South Africa         2        3   \n10   11    133       Pakistan         2        2   \n11   12    145          India         2        1   \n12   13    102          India         2        3   \n13   14    101          India         2        1   \n14   15    127        England         1        2   \n15   16    178    Afghanistan         1        1   \n16   17    163    New Zealand         2        1   \n17   18    116    New Zealand         2   
# ...

# %%
a.to_json("Test2.json")

# %%
a['Score'].unique()
# Out:
# array(['123* ', '180', '163', '100', '119', '124', '112', '115', '135',
#        '145', '133', '102', '101', '127', '178', '116', '253', '122* ',
#        '122', '109', '106', '117', '173', '156', '144', '113', '130',
#        '179', '123', '103', '107', '166', '100* ', '154', '335* ', '111*',
#        '128* ', '200'], dtype=object)

# %%
import seaborn as sns
sns.heatmap(a.corr())
a.corr()
# Out:
# C:\Users\Surya Reddy\AppData\Local\Temp\ipykernel_21112\4039539089.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(a.corr())
# C:\Users\Surya Reddy\AppData\Local\Temp\ipykernel_21112\4039539089.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   a.corr()
#                No.  Position   Innings
# No.       1.000000 -0.434724 -0.165390
# Position -0.434724  1.000000  0.107845
# Innings  -0.165390  0.107845  1.000000

# %%
sns.jointplot(x='Position',y= 'Innings',data=a)

# %%
sns.jointplot(x='Position',y='Innings',data=a,kind='hex')

# %%
sns.jointplot(x='Position',y='Innings',data=a,kind='reg')

# %%
sns.pairplot(a,hue='Ground')

# %%
sns.distplot(a['Innings'])
# Out:
# C:\Users\Surya Reddy\AppData\Local\Temp\ipykernel_21112\1885904783.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a['Innings'])
# <Axes: xlabel='Innings', ylabel='Density'>

# %%
a.head()
# Out:
#    No.  Score        Against  Position  Innings                    Venue  \
# 0    1  123*     New Zealand         2        4   Bellerive Oval, Hobart
# 1    2    180          India         2        2       WACA Ground, Perth
# 2    3    163      Sri Lanka         1        1      The Gabba, Brisbane
# 3    4    100      Sri Lanka         2        1  Adelaide Oval, Adelaide
# 4    5    119   South Africa         1        1  Adelaide Oval, Adelaide
#
#   Ground       Date Result
# 0   Home  09-Dec-11   Lost
# 1   Home  13-Jan-12    Won
# 2   Home  04-Mar-12    Won
# 3   Home  06-Mar-12   Lost
# 4   Home  22-Nov-12  Drawn

# %%
sns.countplot(x='Result',data=a)
# Out:
# <Axes: xlabel='Result', ylabel='count'>

# %%
sns.barplot(x='Result',y='Innings',data=a)
# Out:
# <Axes: xlabel='Result', ylabel='Innings'>

# %%
sns.boxplot(x='Result',y='Innings',data=a,hue='Ground')
# Out:
# <Axes: xlabel='Result', ylabel='Innings'>

# %%
sns.violinplot(x='Result',y='Innings',data=a,hue='Ground')
# Out:
# <Axes: xlabel='Result', ylabel='Innings'>

# %%
pd.merge()
