# %%
class ownlR:
    def __init__(self):
        self.m = None
        self.c = None
    def fit(x_train,y_train):
        num = 0
        den =0
        for i in range(x_train.shape[0]):
            num = nums + ((x_train[i] - x_train.mean()))*(y_train[i] - y_train.mean())
            den = den + ((x_train[i] - x_train.mean())) *((x_train[i] - x_train.mean()))
        self.m = num/den
        self.c = y_train.mean() - (self.m - x_train.mean())
        print(self.m)
        print(self.c)
    def predict(self,x_test):
        return self.m*x_test + self.c

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('placement.csv')

# %%
plt.scatter(df['cgpa'], df['package'])
plt.xlabel('cgpa')
plt.ylabel('package(in lpa)')
# Out:
# Text(0, 0.5, 'package(in lpa)')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df[['cgpa']],df[['package']],test_size = 0.2, random_state=2)

# %%
lrs = ownlR()

# %%
lrs.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 lrs.fit(x_train,y_train)
#
# TypeError: ownlR.fit() takes 2 positional arguments but 3 were given
