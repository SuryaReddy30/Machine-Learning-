# %%
class ownlr():
    def __init__(self):
        self.m = None
        self.c = None
    def fit(x_train,y_train):
        for i in range(x_train.shape[0]):
            num = num + ((x_train[i] - x_train.mean()))*(y_train[i] - y_train.mean())
            den = den + ((x_train[i] - x_train.mean()))**2
        m = num / den
        c = mean_y - (b1*mean_x)
        print(b1,b0)
    def predict(self,x_test):
        return self.m*x_test + self.c

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("headbrain.csv")
df.head()
# Out:
#    Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0       1          1             4512                 1530
# 1       1          1             3738                 1297
# 2       1          1             4261                 1335
# 3       1          1             3777                 1282
# 4       1          1             4177                 1590

# %%
plt.scatter(x=df['Head Size(cm^3)'],y=df['Brain Weight(grams)'])
plt.xlabel('Head Size(cm^3)')
plt.ylabel('Brain Weight(grams)')
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df[['Head Size(cm^3)']],df[['Brain Weight(grams)']],test_size = 0.2, random_state=2)

# %%
x_train.head()
# Out:
#      Head Size(cm^3)
# 18              3095
# 159             3269
# 5               3585
# 169             3566
# 2               4261

# %%
x_test.head()
# Out:
#      Head Size(cm^3)
# 20              3878
# 149             3090
# 30              3787
# 54              4012
# 147             3267

# %%
lr= LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
r2_score = lr.score(y_pred,x_test)
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print(r2_score)
# Out:
# -74.51191779064325

# %%
plt.scatter(df[['Head Size(cm^3)']],df[['Brain Weight(grams)']])
plt.plot(x_test,lr.predict(x_test),color='red')
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')
