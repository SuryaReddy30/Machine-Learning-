# %%
# !pip install -U keras-tuner
# Out:
# Requirement already satisfied: keras-tuner in /usr/local/lib/python3.10/dist-packages (1.4.2)
# Requirement already satisfied: keras-core in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (0.1.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (23.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.31.0)
# Requirement already satisfied: kt-legacy in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (1.0.5)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-tuner) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-tuner) (1.23.5)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-tuner) (13.5.2)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-tuner) (0.0.7)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-tuner) (3.9.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-tuner) (0.1.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2023.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-core->keras-tuner) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-core->keras-tuner) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras-core->keras-tuner) (0.1.2)

# %%
import pandas as pd

# %%
df = pd.read_csv("Churn_Modelling.csv")

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Exited'].value_counts()
# Out:
# 0    7963
# 1    2037
# Name: Exited, dtype: int64

# %%
df['Geography'].value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Male      5457
# Female    4543
# Name: Gender, dtype: int64

# %%
df.drop(columns = ['RowNumber','CustomerId','Surname'],inplace=True)

# %%
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
pd.get_dummies(df,columns=['Geography','Gender'],drop_first=True)
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0                  1        101348.88       1                  0
# 1                  1        112542.58       0                  0
# 2                  0        113931.57       1                  0
# 3                  0         93826.63       0                  0
# 4                  1         79084.10       0                  0
# ...              ...              ...     ...                ...
# 9995               0         96270.64       0                  0
# 9996               1        101699.77       0                  0
# 9997               1         42085.58       1                  0
# 9998               0         92888.52       1                  1
# 9999               0         38190.78       0                  0
#
#       Geography_Spain  Gender_Male
# 0                   0            0
# 1                   1            0
# 2                   0            0
# 3                   0            0
# 4                   1            0
# ...               ...          ...
# 9995                0            1
# 9996                0            1
# 9997                0            0
# 9998                0            1
# 9999                0            0
#
# [10000 rows x 12 columns]

# %%
df.drop(columns = ['Geography','Gender'],inplace=True)

# %%
df
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited
# 0                  1        101348.88       1
# 1                  1        112542.58       0
# 2                  0        113931.57       1
# 3                  0         93826.63       0
# 4                  1         79084.10       0
# ...              ...              ...     ...
# 9995               0         96270.64       0
# 9996               1        101699.77       0
# 9997               1         42085.58       1
# 9998               0         92888.52       1
# 9999               0         38190.78       0
#
# [10000 rows x 9 columns]

# %%
x= df.drop(columns=['Exited'])
y= df['Exited']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=1)

# %%
x
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary
# 0                  1        101348.88
# 1                  1        112542.58
# 2                  0        113931.57
# 3                  0         93826.63
# 4                  1         79084.10
# ...              ...              ...
# 9995               0         96270.64
# 9996               1        101699.77
# 9997               1         42085.58
# 9998               0         92888.52
# 9999               0         38190.78
#
# [10000 rows x 8 columns]

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
x_train.shape
# Out:
# (8000, 8)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
x_train_scaled
# Out:
# array([[-0.23082038, -0.94449979, -0.70174202, ..., -1.55337352,
#          0.97725852,  0.42739449],
#        [-0.25150912, -0.94449979, -0.35520275, ..., -1.55337352,
#         -1.02327069, -1.02548708],
#        [-0.3963303 ,  0.77498705,  0.33787579, ...,  0.64376017,
#          0.97725852, -0.94479772],
#        ...,
#        [ 0.22433188,  0.58393295,  1.3774936 , ...,  0.64376017,
#          0.97725852, -0.14096853],
#        [ 0.13123255,  0.01077067,  1.03095433, ...,  0.64376017,
#          0.97725852,  0.01781218],
#        [ 1.1656695 ,  0.29735181,  0.33787579, ...,  0.64376017,
#         -1.02327069, -1.15822478]])

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.13.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.57.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.13.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.33.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.41.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow) (2.3.7)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow) (3.2.2)

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(11, activation='sigmoid', input_dim=8))  # Update input_dim to 8
model.add(Dense(11, activation='sigmoid'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 11)                99
#
#  dense_7 (Dense)             (None, 11)                132
#
#  dense_8 (Dense)             (None, 1)                 12
#
# =================================================================
# Total params: 243 (972.00 Byte)
# Trainable params: 243 (972.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(x_train,y_train,batch_size=50,epochs=100,verbose=1,validation_split=0.2)
# Out:
# Epoch 1/100
# 128/128 [==============================] - 6s 6ms/step - loss: 0.7324 - accuracy: 0.4769 - val_loss: 0.5899 - val_accuracy: 0.7975
# Epoch 2/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5461 - accuracy: 0.7972 - val_loss: 0.5223 - val_accuracy: 0.7975
# Epoch 3/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5145 - accuracy: 0.7972 - val_loss: 0.5096 - val_accuracy: 0.7975
# Epoch 4/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5074 - accuracy: 0.7972 - val_loss: 0.5052 - val_accuracy: 0.7975
# Epoch 5/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.5042 - accuracy: 0.7972 - val_loss: 0.5020 - val_accuracy: 0.7975
# Epoch 6/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5021 - accuracy: 0.7972 - val_loss: 0.5001 - val_accuracy: 0.7975
# Epoch 7/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5009 - accuracy: 0.7972 - val_loss: 0.4987 - val_accuracy: 0.7975
# Epoch 8/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5001 - accuracy: 0.7972 - val_loss: 0.4978 - val_accuracy: 0.7975
# Epoch 9/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4995 - accuracy: 0.7972 - val_loss: 0.4971 - val_accuracy: 0.7975
# Epoch 10/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4991 - accuracy: 0.7972 - val_loss: 0.4967 - val_accuracy: 0.7975
# Epoch 11/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4988 - accuracy: 0.7972 - val_loss: 0.4965 - val_accuracy: 0.7975
# Epoch 12/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4986 - accuracy: 0.7972 - val_loss: 0.4964 - val_accuracy: 0.7975
# Epoch 13/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4983 - accuracy: 0.7972 - val_loss: 0.4962 - val_accuracy: 0.7975
# Epoch 14/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4982 - accuracy: 0.7972 - val_loss: 0.4961 - val_accuracy: 0.7975
# Epoch 15/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4983 - accuracy: 0.7972 - val_loss: 0.4960 - val_accuracy: 0.7975
# Epoch 16/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4979 - accuracy: 0.7972 - val_loss: 0.4961 - val_accuracy: 0.7975
# Epoch 17/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4979 - accuracy: 0.7972 - val_loss: 0.4960 - val_accuracy: 0.7975
# Epoch 18/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4977 - accuracy: 0.7972 - val_loss: 0.4960 - val_accuracy: 0.7975
# Epoch 19/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4977 - accuracy: 0.7972 - val_loss: 0.4960 - val_accuracy: 0.7975
# Epoch 20/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4976 - accuracy: 0.7972 - val_loss: 0.4960 - val_accuracy: 0.7975
# Epoch 21/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4974 - accuracy: 0.7972 - val_loss: 0.4960 - val_accuracy: 0.7975
# Epoch 22/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4974 - accuracy: 0.7972 - val_loss: 0.4960 - val_accuracy: 0.7975
# Epoch 23/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.4972 - accuracy: 0.7972 - val_loss: 0.4961 - val_accuracy: 0.7975
# Epoch 24/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.4973 - accuracy: 0.7972 - val_loss: 0.4959 - val_accuracy: 0.7975
# Epoch 25/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.4973 - accuracy: 0.7972 - val_loss: 0.4959 - val_accuracy: 0.7975
# Epoch 26/100
# 128/128 [==============================] - 1s 6ms/step - loss: 0.4970 - accuracy: 0.7972 - val_loss: 0.4960 - val_accuracy: 0.7975
# Epoch 27/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.4970 - accuracy: 0.7972 - val_loss: 0.4960 - val_accuracy: 0.7975
# Epoch 28/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4971 - accuracy: 0.7972 - val_loss: 0.4960 - val_accuracy: 0.7975
# Epoch 29/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4969 - accuracy: 0.7972 - val_loss: 0.4960 - val_accuracy: 0.7975
# Epoch 30/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4969 - accuracy: 0.7972 - val_loss: 0.4960 - val_accuracy: 0.7975
# Epoch 31/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4968 - accuracy: 0.7972 - val_loss: 0.4960 - val_accuracy: 0.7975
# Epoch 32/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4969 - accuracy: 0.7972 - val_loss: 0.4960 - val_accuracy: 0.7975
# Epoch 33/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4969 - accuracy: 0.7972 - val_loss: 0.4963 - val_accuracy: 0.7975
# Epoch 34/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4967 - accuracy: 0.7972 - val_loss: 0.4960 - val_accuracy: 0.7975
# Epoch 35/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4968 - accuracy: 0.7972 - val_loss: 0.4961 - val_accuracy: 0.7975
# Epoch 36/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4967 - accuracy: 0.7972 - val_loss: 0.4961 - val_accuracy: 0.7975
# Epoch 37/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4969 - accuracy: 0.7972 - val_loss: 0.4962 - val_accuracy: 0.7975
# Epoch 38/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4967 - accuracy: 0.7972 - val_loss: 0.4961 - val_accuracy: 0.7975
# Epoch 39/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4965 - accuracy: 0.7972 - val_loss: 0.4961 - val_accuracy: 0.7975
# Epoch 40/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.4965 - accuracy: 0.7972 - val_loss: 0.4962 - val_accuracy: 0.7975
# Epoch 41/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4966 - accuracy: 0.7972 - val_loss: 0.4963 - val_accuracy: 0.7975
# Epoch 42/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4965 - accuracy: 0.7972 - val_loss: 0.4962 - val_accuracy: 0.7975
# Epoch 43/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4966 - accuracy: 0.7972 - val_loss: 0.4961 - val_accuracy: 0.7975
# Epoch 44/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4965 - accuracy: 0.7972 - val_loss: 0.4961 - val_accuracy: 0.7975
# Epoch 45/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4964 - accuracy: 0.7972 - val_loss: 0.4961 - val_accuracy: 0.7975
# Epoch 46/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4964 - accuracy: 0.7972 - val_loss: 0.4962 - val_accuracy: 0.7975
# Epoch 47/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4964 - accuracy: 0.7972 - val_loss: 0.4964 - val_accuracy: 0.7975
# Epoch 48/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4964 - accuracy: 0.7972 - val_loss: 0.4962 - val_accuracy: 0.7975
# Epoch 49/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.4964 - accuracy: 0.7972 - val_loss: 0.4963 - val_accuracy: 0.7975
# Epoch 50/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.4964 - accuracy: 0.7972 - val_loss: 0.4964 - val_accuracy: 0.7975
# Epoch 51/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.4964 - accuracy: 0.7972 - val_loss: 0.4962 - val_accuracy: 0.7975
# Epoch 52/100
# 128/128 [==============================] - 1s 6ms/step - loss: 0.4962 - accuracy: 0.7972 - val_loss: 0.4964 - val_accuracy: 0.7975
# Epoch 53/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.4963 - accuracy: 0.7972 - val_loss: 0.4963 - val_accuracy: 0.7975
# Epoch 54/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4962 - accuracy: 0.7972 - val_loss: 0.4962 - val_accuracy: 0.7975
# Epoch 55/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4963 - accuracy: 0.7972 - val_loss: 0.4963 - val_accuracy: 0.7975
# Epoch 56/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4963 - accuracy: 0.7972 - val_loss: 0.4963 - val_accuracy: 0.7975
# Epoch 57/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4962 - accuracy: 0.7972 - val_loss: 0.4963 - val_accuracy: 0.7975
# Epoch 58/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4964 - accuracy: 0.7972 - val_loss: 0.4964 - val_accuracy: 0.7975
# Epoch 59/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4962 - accuracy: 0.7972 - val_loss: 0.4963 - val_accuracy: 0.7975
# Epoch 60/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4962 - accuracy: 0.7972 - val_loss: 0.4962 - val_accuracy: 0.7975
# Epoch 61/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4961 - accuracy: 0.7972 - val_loss: 0.4966 - val_accuracy: 0.7975
# Epoch 62/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4962 - accuracy: 0.7972 - val_loss: 0.4963 - val_accuracy: 0.7975
# Epoch 63/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4961 - accuracy: 0.7972 - val_loss: 0.4963 - val_accuracy: 0.7975
# Epoch 64/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4961 - accuracy: 0.7972 - val_loss: 0.4963 - val_accuracy: 0.7975
# Epoch 65/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4960 - accuracy: 0.7972 - val_loss: 0.4969 - val_accuracy: 0.7975
# Epoch 66/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4963 - accuracy: 0.7972 - val_loss: 0.4964 - val_accuracy: 0.7975
# Epoch 67/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4961 - accuracy: 0.7972 - val_loss: 0.4964 - val_accuracy: 0.7975
# Epoch 68/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4959 - accuracy: 0.7972 - val_loss: 0.4970 - val_accuracy: 0.7975
# Epoch 69/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4959 - accuracy: 0.7972 - val_loss: 0.4965 - val_accuracy: 0.7975
# Epoch 70/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4962 - accuracy: 0.7972 - val_loss: 0.4964 - val_accuracy: 0.7975
# Epoch 71/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.4961 - accuracy: 0.7972 - val_loss: 0.4965 - val_accuracy: 0.7975
# Epoch 72/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4960 - accuracy: 0.7972 - val_loss: 0.4965 - val_accuracy: 0.7975
# Epoch 73/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4960 - accuracy: 0.7972 - val_loss: 0.4965 - val_accuracy: 0.7975
# Epoch 74/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4962 - accuracy: 0.7972 - val_loss: 0.4965 - val_accuracy: 0.7975
# Epoch 75/100
# 128/128 [==============================] - 1s 6ms/step - loss: 0.4960 - accuracy: 0.7972 - val_loss: 0.4964 - val_accuracy: 0.7975
# Epoch 76/100
# 128/128 [==============================] - 1s 6ms/step - loss: 0.4961 - accuracy: 0.7972 - val_loss: 0.4961 - val_accuracy: 0.7975
# Epoch 77/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.4962 - accuracy: 0.7972 - val_loss: 0.4964 - val_accuracy: 0.7975
# Epoch 78/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.4960 - accuracy: 0.7972 - val_loss: 0.4964 - val_accuracy: 0.7975
# Epoch 79/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.4961 - accuracy: 0.7972 - val_loss: 0.4964 - val_accuracy: 0.7975
# Epoch 80/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4959 - accuracy: 0.7972 - val_loss: 0.4964 - val_accuracy: 0.7975
# Epoch 81/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4961 - accuracy: 0.7972 - val_loss: 0.4962 - val_accuracy: 0.7975
# Epoch 82/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4960 - accuracy: 0.7972 - val_loss: 0.4963 - val_accuracy: 0.7975
# Epoch 83/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4961 - accuracy: 0.7972 - val_loss: 0.4964 - val_accuracy: 0.7975
# Epoch 84/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.4959 - accuracy: 0.7972 - val_loss: 0.4965 - val_accuracy: 0.7975
# Epoch 85/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4962 - accuracy: 0.7972 - val_loss: 0.4964 - val_accuracy: 0.7975
# Epoch 86/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4957 - accuracy: 0.7972 - val_loss: 0.4965 - val_accuracy: 0.7975
# Epoch 87/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4960 - accuracy: 0.7972 - val_loss: 0.4964 - val_accuracy: 0.7975
# Epoch 88/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4959 - accuracy: 0.7972 - val_loss: 0.4964 - val_accuracy: 0.7975
# Epoch 89/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4960 - accuracy: 0.7972 - val_loss: 0.4963 - val_accuracy: 0.7975
# Epoch 90/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4958 - accuracy: 0.7972 - val_loss: 0.4964 - val_accuracy: 0.7975
# Epoch 91/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4961 - accuracy: 0.7972 - val_loss: 0.4963 - val_accuracy: 0.7975
# Epoch 92/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4960 - accuracy: 0.7972 - val_loss: 0.4965 - val_accuracy: 0.7975
# Epoch 93/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4959 - accuracy: 0.7972 - val_loss: 0.4965 - val_accuracy: 0.7975
# Epoch 94/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4959 - accuracy: 0.7972 - val_loss: 0.4966 - val_accuracy: 0.7975
# Epoch 95/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4959 - accuracy: 0.7972 - val_loss: 0.4964 - val_accuracy: 0.7975
# Epoch 96/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4960 - accuracy: 0.7972 - val_loss: 0.4964 - val_accuracy: 0.7975
# Epoch 97/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4959 - accuracy: 0.7972 - val_loss: 0.4965 - val_accuracy: 0.7975
# Epoch 98/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4960 - accuracy: 0.7972 - val_loss: 0.4965 - val_accuracy: 0.7975
# Epoch 99/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4958 - accuracy: 0.7972 - val_loss: 0.4966 - val_accuracy: 0.7975
# Epoch 100/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.4958 - accuracy: 0.7972 - val_loss: 0.4965 - val_accuracy: 0.7975

# %%
y_pred = model.predict(x_test)
# Out:
# 63/63 [==============================] - 1s 4ms/step

# %%
y_pred
# Out:
# array([[0.14044476],
#        [0.21193326],
#        [0.14044476],
#        ...,
#        [0.14044476],
#        [0.28604934],
#        [0.24910137]], dtype=float32)

# %%
y_pred = y_pred.argmax(axis=-1)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.7925

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
